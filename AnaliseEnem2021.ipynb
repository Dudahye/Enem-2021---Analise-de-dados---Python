# %% [markdown]
# <a href="https://colab.research.google.com/github/Dudahye/Enem-2021---Analise-de-dados---Python/blob/main/AnaliseEnem2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import matplotlib

# %%
MicrodadosEnem = pd.read_csv('/content/drive/MyDrive/ENEM 2021/MICRODADOS_ENEM_2021.csv',sep=";", encoding="ISO-8859-1")

# %%
MicrodadosEnem.head()
# Out:
#    NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0  210053865474    2021                5       F                1
# 1  210052384164    2021               12       M                1
# 2  210052589243    2021               13       F                3
# 3  210052128335    2021                3       M                1
# 4  210051353021    2021                2       F                1
#
#    TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  TP_ESCOLA  \
# 0            1                 1                1                3          1
# 1            1                 1                1               11          1
# 2            1                 1                1               15          1
# 3            3                 1                2                0          2
# 4            3                 1                2                0          2
#
#    ...  Q016  Q017  Q018 Q019  Q020 Q021  Q022  Q023  Q024  Q025
# ...

# %%
MicrodadosEnem
# Out:
#          NU_INSCRICAO  NU_ANO  TP_FAIXA_ETARIA TP_SEXO  TP_ESTADO_CIVIL  \
# 0        210053865474    2021                5       F                1
# 1        210052384164    2021               12       M                1
# 2        210052589243    2021               13       F                3
# 3        210052128335    2021                3       M                1
# 4        210051353021    2021                2       F                1
# ...               ...     ...              ...     ...              ...
# 3389827  210053249138    2021                7       F                1
# 3389828  210053776013    2021                7       F                1
# 3389829  210052441508    2021               13       F                1
# 3389830  210051139675    2021                7       F                1
# 3389831  210052410399    2021               12       F                2
#
#          TP_COR_RACA  TP_NACIONALIDADE  TP_ST_CONCLUSAO  TP_ANO_CONCLUIU  \
# ...

# %%
MicrodadosEnem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3389832 entries, 0 to 3389831
# Data columns (total 76 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   NU_INSCRICAO            int64
#  1   NU_ANO                  int64
#  2   TP_FAIXA_ETARIA         int64
#  3   TP_SEXO                 object
#  4   TP_ESTADO_CIVIL         int64
#  5   TP_COR_RACA             int64
#  6   TP_NACIONALIDADE        int64
#  7   TP_ST_CONCLUSAO         int64
#  8   TP_ANO_CONCLUIU         int64
#  9   TP_ESCOLA               int64
#  10  TP_ENSINO               float64
#  11  IN_TREINEIRO            int64
#  12  CO_MUNICIPIO_ESC        float64
#  13  NO_MUNICIPIO_ESC        object
#  14  CO_UF_ESC               float64
#  15  SG_UF_ESC               object
#  16  TP_DEPENDENCIA_ADM_ESC  float64
#  17  TP_LOCALIZACAO_ESC      float64
#  18  TP_SIT_FUNC_ESC         float64
#  19  CO_MUNICIPIO_PROVA      int64
#  20  NO_MUNICIPIO_PROVA      object
# ...

# %%
MicrodadosEnem.duplicated().sum()
# Out:
# 0

# %%
MicrodadosEnem.isnull().sum()
# Out:
# NU_INSCRICAO       0
# NU_ANO             0
# TP_FAIXA_ETARIA    0
# TP_SEXO            0
# TP_ESTADO_CIVIL    0
#                   ..
# Q021               2
# Q022               2
# Q023               2
# Q024               2
# Q025               2
# Length: 76, dtype: int64

# %%
MicrodadosEnem['TP_SEXO'].value_counts()
# Out:
# F    2090526
# M    1299306
# Name: TP_SEXO, dtype: int64

# %%
MicrodadosEnem['TP_SEXO'].value_counts().sum()
# Out:
# 3389832

# %%
MicrodadosEnem.columns.values
# Out:
# array(['NU_INSCRICAO', 'NU_ANO', 'TP_FAIXA_ETARIA', 'TP_SEXO',
#        'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE',
#        'TP_ST_CONCLUSAO', 'TP_ANO_CONCLUIU', 'TP_ESCOLA', 'TP_ENSINO',
#        'IN_TREINEIRO', 'CO_MUNICIPIO_ESC', 'NO_MUNICIPIO_ESC',
#        'CO_UF_ESC', 'SG_UF_ESC', 'TP_DEPENDENCIA_ADM_ESC',
#        'TP_LOCALIZACAO_ESC', 'TP_SIT_FUNC_ESC', 'CO_MUNICIPIO_PROVA',
#        'NO_MUNICIPIO_PROVA', 'CO_UF_PROVA', 'SG_UF_PROVA',
#        'TP_PRESENCA_CN', 'TP_PRESENCA_CH', 'TP_PRESENCA_LC',
#        'TP_PRESENCA_MT', 'CO_PROVA_CN', 'CO_PROVA_CH', 'CO_PROVA_LC',
#        'CO_PROVA_MT', 'NU_NOTA_CN', 'NU_NOTA_CH', 'NU_NOTA_LC',
#        'NU_NOTA_MT', 'TX_RESPOSTAS_CN', 'TX_RESPOSTAS_CH',
#        'TX_RESPOSTAS_LC', 'TX_RESPOSTAS_MT', 'TP_LINGUA',
#        'TX_GABARITO_CN', 'TX_GABARITO_CH', 'TX_GABARITO_LC',
#        'TX_GABARITO_MT', 'TP_STATUS_REDACAO', 'NU_NOTA_COMP1',
#        'NU_NOTA_COMP2', 'NU_NOTA_COMP3', 'NU_NOTA_COMP4', 'NU_NOTA_COMP5',
# ...

# %%
microdadosEnemSelecionados=['SG_UF_PROVA','NO_MUNICIPIO_PROVA','TP_FAIXA_ETARIA', 'TP_SEXO',
       'TP_ESTADO_CIVIL', 'TP_COR_RACA', 'TP_NACIONALIDADE']

# %%
microdadosEnemSelect=MicrodadosEnem.filter(items=microdadosEnemSelecionados)

# %%
microdadosEnemSelect.head()
# Out:
#   SG_UF_PROVA     NO_MUNICIPIO_PROVA  TP_FAIXA_ETARIA TP_SEXO  \
# 0          MG              Nova Lima                5       F
# 1          AL                 Maceió               12       M
# 2          SP  Ferraz de Vasconcelos               13       F
# 3          CE                  Crato                3       M
# 4          CE                Acarape                2       F
#
#    TP_ESTADO_CIVIL  TP_COR_RACA  TP_NACIONALIDADE
# 0                1            1                 1
# 1                1            1                 1
# 2                3            1                 1
# 3                1            3                 1
# 4                1            3                 1

# %%
  microdadosEnemSelect[0:100]
# Out:
#    SG_UF_PROVA     NO_MUNICIPIO_PROVA  TP_FAIXA_ETARIA TP_SEXO  \
# 0           MG              Nova Lima                5       F
# 1           AL                 Maceió               12       M
# 2           SP  Ferraz de Vasconcelos               13       F
# 3           CE                  Crato                3       M
# 4           CE                Acarape                2       F
# ..         ...                    ...              ...     ...
# 95          BA               Camaçari               12       F
# 96          BA              Vera Cruz                3       M
# 97          RS           Porto Alegre                4       F
# 98          PE               Limoeiro                5       F
# 99          GO                Jaraguá                2       F
#
#     TP_ESTADO_CIVIL  TP_COR_RACA  TP_NACIONALIDADE
# 0                 1            1                 1
# 1                 1            1                 1
# 2                 3            1                 1
# ...

# %%
coluna_no_municipio_prova= microdadosEnemSelect['NO_MUNICIPIO_PROVA']

# %%
coluna_no_municipio_prova[0:100]
# Out:
# 0                 Nova Lima
# 1                    Maceió
# 2     Ferraz de Vasconcelos
# 3                     Crato
# 4                   Acarape
#               ...
# 95                 Camaçari
# 96                Vera Cruz
# 97             Porto Alegre
# 98                 Limoeiro
# 99                  Jaraguá
# Name: NO_MUNICIPIO_PROVA, Length: 100, dtype: object

# %%
coluna_sigla_uf_prova = microdadosEnemSelect['SG_UF_PROVA']

# %%
coluna_sigla_uf_prova.value_counts().sort_index()
# Out:
# AC     20336
# AL     56584
# AM     89778
# AP     21774
# BA    266194
# CE    220517
# DF     67501
# ES     64181
# GO    136915
# MA    127905
# MG    327829
# MS     42490
# MT     56085
# PA    185978
# PB    102002
# PE    193616
# PI     79969
# PR    144282
# RJ    238347
# RN     80820
# RO     32801
# RR      8056
# RS    150484
# SC     80765
# SE     53796
# SP    509954
# TO     30873
# Name: SG_UF_PROVA, dtype: int64

# %%
coluna_sigla_uf_prova.hist(bins=50)
